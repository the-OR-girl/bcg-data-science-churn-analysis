# %% [markdown]
# # Exploratory Data Analysis Starter
#
# ## Import packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %% [markdown]
# ---
#
# ## Loading data with Pandas
#
# We need to load `client_data.csv` and `price_data.csv` into individual dataframes so that we can work with them in Python. For this notebook and all further notebooks, it will be assumed that the CSV files will the placed in the same file location as the notebook. If they are not, please adjust the directory within the `read_csv` method accordingly.

# %%
client_df = pd.read_csv('./client_data (1).csv')
price_df = pd.read_csv('./price_data (1).csv')

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\sraba
# ...

# %% [markdown]
# You can view the first 3 rows of a dataframe using the `head` method. Similarly, if you wanted to see the last 3, you can use `tail(3)`

# %%
client_df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %%
price_df.head(3)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %% [markdown]
# ---
#
# ## Descriptive statistics of data
#
# ### Data types
#
# It is useful to first understand the data that you're dealing with along with the data types of each column. The data types may dictate how you transform and engineer features.
#
# To get an overview of the data types within a data frame, use the `info()` method.

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        14606 non-null  object
#  1   channel_sales             14606 non-null  object
#  2   cons_12m                  14606 non-null  int64
#  3   cons_gas_12m              14606 non-null  int64
#  4   cons_last_month           14606 non-null  int64
#  5   date_activ                14606 non-null  object
#  6   date_end                  14606 non-null  object
#  7   date_modif_prod           14606 non-null  object
#  8   date_renewal              14606 non-null  object
#  9   forecast_cons_12m         14606 non-null  float64
#  10  forecast_cons_year        14606 non-null  int64
#  11  forecast_discount_energy  14606 non-null  float64
#  12  forecast_meter_rent_12m   14606 non-null  float64
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Statistics
#
# Now let's look at some statistics about the datasets. We can do this by using the `describe()` method.

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# ---
#
# ## Data visualization
#
# If you're working in Python, two of the most popular packages for visualization are `matplotlib` and `seaborn`. We highly recommend you use these, or at least be familiar with them because they are ubiquitous!
#
# Below are some functions that you can use to get started with visualizations.

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# Thhe first function `plot_stacked_bars` is used to plot a stacked bar chart. An example of how you could use this is shown below:

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %% [markdown]
# The second function `annotate_bars` is used by the first function, but the third function `plot_distribution` helps you to plot the distribution of a numeric column. An example of how it can be used is given below:

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(consumption, 'cons_12m', axs)

# %%
print("CLIENT DATA TYPES")
client_df.info()

print("\nPRICE DATA TYPES")
price_df.info()
# Out:
# CLIENT DATA TYPES
# <class 'pandas.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  str
#  1   channel_sales                   14606 non-null  str
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  str
#  6   date_end                        14606 non-null  str
#  7   date_modif_prod                 14606 non-null  str
#  8   date_renewal                    14606 non-null  str
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
print("CLIENT DATA - DESCRIPTIVE STATISTICS")
display(client_df.describe())

print("\nPRICE DATA - DESCRIPTIVE STATISTICS")
display(price_df.describe())
# Out:
# CLIENT DATA - DESCRIPTIVE STATISTICS
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# ...

# %%
print("CLIENT DATA")
display(client_df.head())

print("\nPRICE DATA")
display(price_df.head())
# Out:
# CLIENT DATA
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
print("MISSING VALUES - CLIENT DATA")
print(client_df.isnull().sum())

print("\nMISSING VALUES - PRICE DATA")
print(price_df.isnull().sum())
# Out:
# MISSING VALUES - CLIENT DATA
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# ...

# %%
print("UNIQUE VALUES IN CLIENT DATA")

for column in client_df.columns:
    print(column, ":", client_df[column].nunique())
    print("\nUNIQUE VALUES IN PRICE DATA")

for column in price_df.columns:
    print(column, ":", price_df[column].nunique())
# Out:
# UNIQUE VALUES IN CLIENT DATA
# id : 14606
#
# UNIQUE VALUES IN PRICE DATA
# channel_sales : 8
#
# UNIQUE VALUES IN PRICE DATA
# cons_12m : 11065
#
# UNIQUE VALUES IN PRICE DATA
# cons_gas_12m : 2112
#
# UNIQUE VALUES IN PRICE DATA
# cons_last_month : 4751
#
# UNIQUE VALUES IN PRICE DATA
# date_activ : 1796
#
# UNIQUE VALUES IN PRICE DATA
# date_end : 368
#
# UNIQUE VALUES IN PRICE DATA
# date_modif_prod : 2129
#
# UNIQUE VALUES IN PRICE DATA
# date_renewal : 386
#
# UNIQUE VALUES IN PRICE DATA
# forecast_cons_12m : 13993
#
# UNIQUE VALUES IN PRICE DATA
# forecast_cons_year : 4218
#
# UNIQUE VALUES IN PRICE DATA
# forecast_discount_energy : 12
#
# UNIQUE VALUES IN PRICE DATA
# forecast_meter_rent_12m : 3528
#
# UNIQUE VALUES IN PRICE DATA
# forecast_price_energy_off_peak : 516
#
# UNIQUE VALUES IN PRICE DATA
# forecast_price_energy_peak : 329
#
# UNIQUE VALUES IN PRICE DATA
# forecast_price_pow_off_peak : 41
#
# UNIQUE VALUES IN PRICE DATA
# has_gas : 2
#
# ...

# %%
churn_counts = client_df['churn'].value_counts()

print(churn_counts)

print("\nChurn percentage:")
print(client_df['churn'].value_counts(normalize=True) * 100)
# Out:
# churn
# 0    13187
# 1     1419
# Name: count, dtype: int64
#
# Churn percentage:
# churn
# 0    90.284814
# 1     9.715186
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=client_df, x='churn')

plt.title('Customer Churn Distribution')
plt.xlabel('Churn (0 = Retained, 1 = Churned)')
plt.ylabel('Number of Customers')

plt.show()

# %%
consumption_columns = [
    'cons_12m',
    'cons_gas_12m',
    'cons_last_month',
    'imp_cons'
]

client_df[consumption_columns].hist(
    figsize=(12, 8),
    bins=30
)

plt.suptitle('Distribution of Energy Consumption Variables')
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

for ax, column in zip(axes.flatten(), consumption_columns):
    sns.boxplot(data=client_df, x='churn', y=column, ax=ax)
    ax.set_title(f'{column} by Churn Status')
    ax.set_xlabel('Churn (0 = Retained, 1 = Churned)')

plt.tight_layout()
plt.show()

# %%
price_df.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  str
#  1   price_date          193002 non-null  str
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), str(2)
# memory usage: 11.8 MB

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %%
print(price_df.columns.tolist())
# Out:
# ['id', 'price_date', 'price_off_peak_var', 'price_peak_var', 'price_mid_peak_var', 'price_off_peak_fix', 'price_peak_fix', 'price_mid_peak_fix']

# %%
price_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  str
#  1   price_date          193002 non-null  str
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), str(2)
# memory usage: 11.8 MB

# %%
price_columns = [
    'price_off_peak_var',
    'price_peak_var',
    'price_mid_peak_var',
    'price_off_peak_fix',
    'price_peak_fix',
    'price_mid_peak_fix'
]

fig, axes = plt.subplots(2, 3, figsize=(16, 9))

for ax, column in zip(axes.flatten(), price_columns):
    sns.histplot(price_df[column], bins=30, kde=True, ax=ax)
    ax.set_title(f'Distribution of {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

sns.boxplot(data=price_df[price_columns])

plt.title('Distribution of Electricity Price Variables')
plt.xlabel('Price Variables')
plt.ylabel('Price')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
price_df['price_date'] = pd.to_datetime(price_df['price_date'])

print(price_df['price_date'].min())
print(price_df['price_date'].max())
price_df.groupby('price_date')[price_columns].mean().plot(
    figsize=(16, 7)
)

plt.title('Average Electricity Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Average Price')
plt.legend(title='Price Type')
plt.tight_layout()
plt.show()
# Out:
# 2015-01-01 00:00:00
# 2015-12-01 00:00:00

# %%
print(client_df.columns.tolist())
client_df.info()
# Out:
# ['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'date_activ', 'date_end', 'date_modif_prod', 'date_renewal', 'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy', 'forecast_meter_rent_12m', 'forecast_price_energy_off_peak', 'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas', 'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act', 'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn']
# <class 'pandas.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  str
#  1   channel_sales                   14606 non-null  str
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
# ...

# %%
client_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  str
#  1   channel_sales                   14606 non-null  str
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  str
#  6   date_end                        14606 non-null  str
#  7   date_modif_prod                 14606 non-null  str
#  8   date_renewal                    14606 non-null  str
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
print(client_df['churn'].value_counts())
print("\nPercentage:")
print(client_df['churn'].value_counts(normalize=True) * 100)
# Out:
# churn
# 0    13187
# 1     1419
# Name: count, dtype: int64
#
# Percentage:
# churn
# 0    90.284814
# 1     9.715186
# Name: proportion, dtype: float64

# %%
churn_counts = client_df['churn'].value_counts()

plt.figure(figsize=(6, 4))

sns.barplot(
    x=churn_counts.index,
    y=churn_counts.values
)

plt.title('Customer Churn Distribution')
plt.xlabel('Churn Status (0 = Retained, 1 = Churned)')
plt.ylabel('Number of Customers')

plt.show()

# %%
churn_percentage = client_df['churn'].value_counts(normalize=True) * 100

plt.figure(figsize=(6, 4))

sns.barplot(
    x=churn_percentage.index,
    y=churn_percentage.values
)

plt.title('Customer Churn Percentage')
plt.xlabel('Churn Status (0 = Retained, 1 = Churned)')
plt.ylabel('Percentage of Customers')

plt.ylim(0, 100)
plt.show()

# %%
client_df[['id', 'churn']].head()
# Out:
#                                  id  churn
# 0  24011ae4ebbe3035111d65fa7c15bc57      1
# 1  d29c2c54acc38ff3c0614d0a653813dd      0
# 2  764c75f661154dac3a6c254cd082ea7d      0
# 3  bba03439a292a1e166f80264c16191cb      0
# 4  149d57cf92fc41cf94415803a877cb4b      0

# %%
price_df[['id', 'price_date']].head()
# Out:
#                                  id price_date
# 0  038af19179925da21a25619c5a24b745 2015-01-01
# 1  038af19179925da21a25619c5a24b745 2015-02-01
# 2  038af19179925da21a25619c5a24b745 2015-03-01
# 3  038af19179925da21a25619c5a24b745 2015-04-01
# 4  038af19179925da21a25619c5a24b745 2015-05-01

# %%
# Calculate the average price for each customer
customer_prices = price_df.groupby('id')[price_columns].mean().reset_index()

customer_prices.head()
# Out:
#                                  id  price_off_peak_var  price_peak_var  \
# 0  0002203ffbb812588b632b9e628cc38d            0.124338        0.103794
# 1  0004351ebdd665e6ee664792efc4fd13            0.146426        0.000000
# 2  0010bcc39e42b3c2131ed2ce55246e3c            0.181558        0.000000
# 3  0010ee3855fdea87602a5b7aba8e42de            0.118757        0.098292
# 4  00114d74e963e47177db89bc70108537            0.147926        0.000000
#
#    price_mid_peak_var  price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# 0            0.073160           40.701732       24.421038           16.280694
# 1            0.000000           44.385450        0.000000            0.000000
# 2            0.000000           45.319710        0.000000            0.000000
# 3            0.069032           40.647427       24.388455           16.258971
# 4            0.000000           44.266930        0.000000            0.000000

# %%
# Add churn information to the customer-level price data
price_churn_df = customer_prices.merge(
    client_df[['id', 'churn']],
    on='id',
    how='inner'
)

price_churn_df.head()
# Out:
#                                  id  price_off_peak_var  price_peak_var  \
# 0  0002203ffbb812588b632b9e628cc38d            0.124338        0.103794
# 1  0004351ebdd665e6ee664792efc4fd13            0.146426        0.000000
# 2  0010bcc39e42b3c2131ed2ce55246e3c            0.181558        0.000000
# 3  00114d74e963e47177db89bc70108537            0.147926        0.000000
# 4  0013f326a839a2f6ad87a1859952d227            0.126076        0.105542
#
#    price_mid_peak_var  price_off_peak_fix  price_peak_fix  price_mid_peak_fix  \
# 0            0.073160           40.701732       24.421038           16.280694
# 1            0.000000           44.385450        0.000000            0.000000
# 2            0.000000           45.319710        0.000000            0.000000
# 3            0.000000           44.266930        0.000000            0.000000
# 4            0.074921           40.728885       24.437330           16.291555
#
#    churn
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
print("Customers in client data:", client_df['id'].nunique())
print("Customers in price data:", price_df['id'].nunique())
print("Customers after merge:", price_churn_df['id'].nunique())
# Out:
# Customers in client data: 14606
# Customers in price data: 16096
# Customers after merge: 14606

# %%
price_by_churn = price_churn_df.groupby('churn')[price_columns].mean()

price_by_churn
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# churn
# 0                0.142375        0.051579            0.027729
# 1                0.141887        0.056562            0.033355
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# churn
# 0               42.903812        9.274093            5.983379
# 1               43.161941       11.196663            7.159896

# %%
plt.figure(figsize=(14, 6))

sns.boxplot(
    data=price_churn_df,
    x='churn',
    y='price_off_peak_var'
)

plt.title('Off-Peak Variable Price by Churn Status')
plt.xlabel('Churn (0 = Retained, 1 = Churned)')
plt.ylabel('Average Off-Peak Variable Price')

plt.show()

# %%
price_by_churn.T.plot(
    kind='bar',
    figsize=(14, 7)
)

plt.title('Average Price by Customer Churn Status')
plt.xlabel('Price Component')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.legend(['Retained', 'Churned'], title='Customer Status')
plt.tight_layout()
plt.show()

# %%
client_df.describe().T
# Out:
#                                   count           mean            std  min  \
# cons_12m                        14606.0  159220.286252  573465.264198  0.0
# cons_gas_12m                    14606.0   28092.375325  162973.059057  0.0
# cons_last_month                 14606.0   16090.269752   64364.196422  0.0
# forecast_cons_12m               14606.0    1868.614880    2387.571531  0.0
# forecast_cons_year              14606.0    1399.762906    3247.786255  0.0
# forecast_discount_energy        14606.0       0.966726       5.108289  0.0
# forecast_meter_rent_12m         14606.0      63.086871      66.165783  0.0
# forecast_price_energy_off_peak  14606.0       0.137283       0.024623  0.0
# forecast_price_energy_peak      14606.0       0.050491       0.049037  0.0
# forecast_price_pow_off_peak     14606.0      43.130056       4.485988  0.0
# imp_cons                        14606.0     152.786896     341.369366  0.0
# ...

# %%
print(client_df.columns.tolist())
# Out:
# ['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'date_activ', 'date_end', 'date_modif_prod', 'date_renewal', 'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy', 'forecast_meter_rent_12m', 'forecast_price_energy_off_peak', 'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas', 'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act', 'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn']

# %%
client_df.describe().T
# Out:
#                                   count           mean            std  min  \
# cons_12m                        14606.0  159220.286252  573465.264198  0.0
# cons_gas_12m                    14606.0   28092.375325  162973.059057  0.0
# cons_last_month                 14606.0   16090.269752   64364.196422  0.0
# forecast_cons_12m               14606.0    1868.614880    2387.571531  0.0
# forecast_cons_year              14606.0    1399.762906    3247.786255  0.0
# forecast_discount_energy        14606.0       0.966726       5.108289  0.0
# forecast_meter_rent_12m         14606.0      63.086871      66.165783  0.0
# forecast_price_energy_off_peak  14606.0       0.137283       0.024623  0.0
# forecast_price_energy_peak      14606.0       0.050491       0.049037  0.0
# forecast_price_pow_off_peak     14606.0      43.130056       4.485988  0.0
# imp_cons                        14606.0     152.786896     341.369366  0.0
# ...

# %%
print(client_df.columns.tolist())
# Out:
# ['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'date_activ', 'date_end', 'date_modif_prod', 'date_renewal', 'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy', 'forecast_meter_rent_12m', 'forecast_price_energy_off_peak', 'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas', 'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act', 'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn']

# %%
numeric_columns = client_df.select_dtypes(include='number').columns

client_df[numeric_columns].hist(
    figsize=(16, 12),
    bins=30
)

plt.suptitle('Distribution of Customer Variables')
plt.tight_layout()
plt.show()

# %%
for column in numeric_columns:
    if column != 'churn':
        plt.figure(figsize=(6, 4))
        sns.boxplot(data=client_df, x='churn', y=column)
        plt.title(f'{column} by Churn Status')
        plt.xlabel('Churn (0 = Retained, 1 = Churned)')
        plt.ylabel(column)
        plt.tight_layout()
        plt.show()
